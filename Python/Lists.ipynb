# %% [markdown]
# ### Creating List

# %%
empty_list = []

# fruits 
fruits = ["apple", "mango", "banana"]

friends = ["mary", "john", "bob"]

numbers = [1,2,3,4,5]

booleans = [True , False, True]

mix = ["apple", 24 , 24.5 , False]

# %%
mix
# Out:
# ['apple', 24, 24.5, False]

# %%
friends
# Out:
# ['mary', 'john', 'bob']

# %% [markdown]
# ## Access items of list

# %%
friends[0]
# Out:
# 'mary'

# %%
friends[1]
# Out:
# 'john'

# %%
# slicing the list 
friends[0:1]
# Out:
# ['mary']

# %%
friends[0:2]
# Out:
# ['mary', 'john']

# %% [markdown]
# ### Methods

# %%
friends.append("Mosh")

# %%
friends
# Out:
# ['mary', 'john', 'bob', 'Mosh']

# %%
friends.insert(1, "Karan")

# %%
friends
# Out:
# ['mary', 'Karan', 'john', 'bob', 'Mosh']

# %%
friends.remove("bob")

# %%
friends
# Out:
# ['mary', 'Karan', 'john', 'Mosh']

# %%
friends.pop()
# Out:
# 'Mosh'

# %%
friends
# Out:
# ['mary', 'Karan', 'john']
