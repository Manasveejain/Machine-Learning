# %% [markdown]
# #### Basic Syntax

# %%
print("Hello,World!")
# Out:
# Hello,World!

# %%
def greet(name):
    print(f"Hello", {name})

# %% [markdown]
# ### Variable

# %%
first_name = "Mary"
last_name = "Jane"
age = 24

# %%
print(first_name)
print(last_name)
print(age)
# Out:
# Mary
# Jane
# 24

# %% [markdown]
# ### Basic Data Types

# %%
first_name = "Mary"
last_name = "Jane"
ageInYears = 24
weightInKg = 72.5
isMarried = True

# %%
print(first_name)
print(last_name)
print(ageInYears)
# Out:
# Mary
# Jane
# 24

# %%
type(first_name)
# Out:
# str

# %%
type(ageInYears)
# Out:
# int

# %%
type(weightInKg)
# Out:
# float

# %%
type(isMarried)
# Out:
# bool

# %%
print(type(ageInYears))
# Out:
# <class 'int'>

# %% [markdown]
# ### operators

# %%
# Arithmetic
a =10
b= 3
print(a+b)
print(a-b)
print(a/b)
print(a*b)
# float division
print(a//b)
# exp
print(a**b)
# Out:
# 13
# 7
# 3.3333333333333335
# 30
# 3
# 1000

# %%
#logical opr
a = True
b = False

print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %%
#comparison opr
a = 10
b = 5
print(a == b)
print(a > b)
print(a < b)
print(a >= b)
print(a >= b)
print(a != b)
# Out:
# False
# True
# False
# True
# True
# True

# %%
# assignement opr
a= 5
a = a+1
print(a)
# Out:
# 6
